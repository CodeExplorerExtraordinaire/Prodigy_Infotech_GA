# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeExplorerExtraordinaire/Prodigy_Infotech_GA/blob/main/PRODIGY_GA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install min-dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 59.9 MB/s eta 0:00:00
# ...

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = "creepy doll enjoying fireworks atBurj Khalifa Dubai"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 30.7 s, sys: 232 ms, total: 30.9 s
# Wall time: 32.7 s

# %%
text1 = "porsche and ferrari on the road of paris"
seed = 6
grid_size = 2

display(model.generate_image(text1, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
text2="Indian flag on the surface of moon"
seed=6
grid_size=2

display(model.generate_image(text2,seed,grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
